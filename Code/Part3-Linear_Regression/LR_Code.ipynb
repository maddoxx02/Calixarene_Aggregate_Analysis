# %% [markdown]
# # RD Kit Metrics vs Metrics - Linear Regression

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 2000)
from tqdm import trange
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# -------

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestClassifier
from math import comb
from itertools import combinations
import re
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Prediction of Metrics using RDKIT Descriptors  - RD KIT

# %% [markdown]
# Considering Median of P_Values accross all three metrics as the boundary condition for meaningful Values

# %%
p_val_df_significant['P_Value'].median()
# Out:
# 0.022252281178379272

# %% [markdown]
# There is also the option of using the Third Quartile

# %%
np.percentile(p_val_df_significant['P_Value'], 75)
# Out:
# 0.03365016836371852

# %% [markdown]
# ------

# %%
def model_maker(dataframe, case):

    flag = 0
    if case == 1:
        # mean_particle_size_(mps)
        flag = 1
        
    elif case == 2:
        # Polar_dispersity
        flag = 2
        
    elif case == 3:
        # Area_Sphere_Substance
        flag = 3
        
    data = dataframe.copy()
    data_cols = dataframe.columns[6:]
    n = len(dataframe.columns) - 6  # length of n in nCr
    perms = 0   # Stores total number of permutations possible 
    combo = []  # Sotres r for nCr
    
    for i in range(n, 0, -1):
        combo.append(i)
        perms = perms + comb(n, i)
        
    all_combinations = []
    for r in range(1, n + 1):
        combs = combinations(data_cols, r)
        all_combinations.extend(combs)
    
    
    full_frame = [] # to store result of LR for all combinations 
    temp_frame = []
    
    for a in trange(len(all_combinations)):

        if len(all_combinations[a]) == 2:
            temp_frame = data[[all_combinations[a][0],
                               all_combinations[a][1]]].copy()

        elif len(all_combinations[a]) == 3:
            temp_frame = data[[all_combinations[a][0],
                               all_combinations[a][1],
                               all_combinations[a][2]]].copy()

        elif len(all_combinations[a]) == 4:
            temp_frame = data[[all_combinations[a][0],
                               all_combinations[a][1],
                               all_combinations[a][2],
                               all_combinations[a][3]]].copy()

        else:
            temp_frame = data[[all_combinations[a][0]]].copy()

        if flag == 1:
            X_train, X_test, y_train, y_test = train_test_split(temp_frame,  
                                                        data[['mean_particle_size_(mps)']],
                                                        test_size=0.3, random_state=0)
        elif flag == 2:
            X_train, X_test, y_train, y_test = train_test_split(temp_frame,  
                                                        data[['Polar_dispersity']],
                                                        test_size=0.3, random_state=0)
        elif flag == 3:
            X_train, X_test, y_train, y_test = train_test_split(temp_frame,  
                                                        data[['Area_Sphere_Substance']],
                                                        test_size=0.3, random_state=0)
                
            
        reg = LinearRegression().fit(X_train, y_train)
        pred = reg.predict(X_test)
        scores = []
        coeffs = []
        desc_create = []
        a1 = reg.coef_
        b1 = mean_squared_error(y_test, pred)
        c1 = r2_score(y_test, pred)
        d1 = mean_absolute_error(y_test, pred)
        
        if len(a1[0]) == 1:
            desc_create = pd.DataFrame([all_combinations[a][0],'-','-','-']
                                      ).transpose().rename(columns = {0:'Desc_1',1:'Desc_2',2:'Desc_3', 3:'Desc_4'})
            scores = pd.DataFrame([b1,c1,d1]).transpose().rename(columns = {0:'MSE', 1:'r2',2:'MAE'})
            #coeffs = pd.DataFrame(a1)
            coeffs = pd.DataFrame([a1[0][0], 0,0,0]).transpose().rename(
                columns = {0:'C1', 1: 'C2', 2: 'C3', 3:'C4'})
            main_frame = pd.concat([desc_create,scores, coeffs], axis = 1)
            
            
        elif len(a1[0]) == 2:
            desc_create = pd.DataFrame([all_combinations[a][0],all_combinations[a][1],'-','-']
                                      ).transpose().rename(columns = {0:'Desc_1',1:'Desc_2',2:'Desc_3', 3:'Desc_4'})
            scores = pd.DataFrame([b1,c1,d1]).transpose().rename(columns = {0:'MSE', 1:'r2',2:'MAE'})
            #coeffs = pd.DataFrame(a1)
            coeffs = pd.DataFrame([a1[0][0],a1[0][1],0,0]).transpose().rename(
                columns = {0:'C1', 1: 'C2', 2: 'C3', 3:'C4'})
            main_frame = pd.concat([desc_create,scores, coeffs], axis = 1)
        
        elif len(a1[0]) == 3:
            desc_create = pd.DataFrame([all_combinations[a][0],all_combinations[a][1],all_combinations[a][2],'-']
                                      ).transpose().rename(columns = {0:'Desc_1',1:'Desc_2',2:'Desc_3', 3:'Desc_4'})
            scores = pd.DataFrame([b1,c1,d1]).transpose().rename(columns = {0:'MSE', 1:'r2',2:'MAE'})
            #coeffs = pd.DataFrame(a1)
            coeffs = pd.DataFrame([a1[0][0],a1[0][1],a1[0][2],0]).transpose().rename(
                columns = {0:'C1', 1: 'C2', 2: 'C3', 3:'C4'})
            main_frame = pd.concat([desc_create,scores, coeffs], axis = 1)
            
        elif len(a1[0]) == 4:
            desc_create = pd.DataFrame([all_combinations[a][0],all_combinations[a][1],all_combinations[a][2],all_combinations[a][3]]
                                      ).transpose().rename(columns = {0:'Desc_1',1:'Desc_2',2:'Desc_3', 3:'Desc_4'})
            scores = pd.DataFrame([b1,c1,d1]).transpose().rename(columns = {0:'MSE', 1:'r2',2:'MAE'})
            #coeffs = pd.DataFrame(a1)
            coeffs = pd.DataFrame([a1[0][0],a1[0][1],a1[0][2],a1[0][3]]).transpose().rename(
                columns = {0:'C1', 1: 'C2', 2: 'C3', 3:'C4'})
            main_frame = pd.concat([desc_create,scores, coeffs], axis = 1)
            
               
        if a == 0:
            full_frame = main_frame.copy()
        else:
            full_frame = pd.concat([full_frame, main_frame], ignore_index = True)
        
        
    return full_frame

# %% [markdown]
# -----------

# %% [markdown]
# ----------

# %% [markdown]
# # Metric 1: Mean Particle Size

# %%
base_data_1 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_1_(RDKIT)\Baseline_Metrics_MPS.csv")
base_data_1
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  \
# 0    156        1         23         23       0.00010
# 1    156        1         23          4       0.00010
# 2    156        1          4         23       0.00010
# 3    156        1         23         23       0.00001
# 4    156        2         23         23       0.00010
# 5    156        2         23         23       0.00001
# 6    159        1         23         23       0.00010
# 7    159        1         23         23       0.00001
# 8    159        2         23         23       0.00010
# 9    159        2         23         23       0.00001
# 10   159        1         23          4       0.00010
# 11   159        1          4         23       0.00010
#
#     mean_particle_size_(mps)  TPSA_C  PEOE_VSA6_C  PEOE_VSA6_S
# 0                 566.363793   77.38   130.132386    34.802820
# 1                 538.820596   77.38   130.132386    34.802820
# 2                 221.955591   77.38   130.132386    34.802820
# 3                 272.233927   77.38   130.132386    34.802820
# 4                 551.931930   77.38   130.132386    35.895287
# 5                 262.359462   77.38   130.132386    35.895287
# 6                   0.000000  264.86    47.047540    34.802820
# 7                 423.373199  264.86    47.047540    34.802820
# 8                 333.662212  264.86    47.047540    35.895287
# 9                 290.411224  264.86    47.047540    35.895287
# 10                703.277095  264.86    47.047540    34.802820
# 11                  0.000000  264.86    47.047540    34.802820

# %%
test = model_maker(base_data_1,1)
test
# Out:
#         Desc_1       Desc_2       Desc_3 Desc_4            MSE        r2  \
# 0       TPSA_C            -            -      -  100366.884089  0.009554
# 1  PEOE_VSA6_C            -            -      -  100366.884089  0.009554
# 2  PEOE_VSA6_S            -            -      -  120581.874595 -0.189933
# 3       TPSA_C  PEOE_VSA6_C            -      -  100366.884089  0.009554
# 4       TPSA_C  PEOE_VSA6_S            -      -  131580.608512 -0.298471
# 5  PEOE_VSA6_C  PEOE_VSA6_S            -      -  131580.608512 -0.298471
# 6       TPSA_C  PEOE_VSA6_C  PEOE_VSA6_S      -  131580.608512 -0.298471
#
#           MAE         C1          C2          C3   C4
# 0  308.002807  -0.123735    0.000000    0.000000  0.0
# 1  308.002807   0.279206    0.000000    0.000000  0.0
# 2  341.070204 -99.839879    0.000000    0.000000  0.0
# 3  308.002807  -0.103423    0.045834    0.000000  0.0
# 4  354.055691   0.188900 -114.968007    0.000000  0.0
# 5  354.055691  -0.426251 -114.968007    0.000000  0.0
# 6  354.055691   0.157891   -0.069972 -114.968007  0.0

# %%
test.to_csv("Results_RDKIT_MPS.csv", index = False)

# %% [markdown]
# ------

# %% [markdown]
# # Metric 2 = Polar Dispersity
#
# 20 Relations

# %%
M2_RD_Var = p_val_df_significant[p_val_df_significant['Synthesis_Metric']=='Polar_dispersity'].reset_index(drop = True)

# %%
M2_RD_Var[M2_RD_Var['P_Value']>=0.0225]
# Out:
#                  RD_KIT_Desc  Synthesis_Metric   P_Value
# 0                VSA_EState2  Polar_dispersity   0.04969
# 1                EState_VSA8  Polar_dispersity  0.044339
# 2                 SlogP_VSA4  Polar_dispersity  0.042655
# 3   NumAliphaticHeterocycles  Polar_dispersity  0.039389
# 4          NumAliphaticRings  Polar_dispersity  0.039389
# 5                EState_VSA2  Polar_dispersity  0.034788
# 6                    NOCount  Polar_dispersity  0.030475
# 7           FpDensityMorgan1  Polar_dispersity  0.030069
# 8               EState_VSA10  Polar_dispersity  0.030002
# 9                   fr_ether  Polar_dispersity   0.02465
# 10                      TPSA  Polar_dispersity  0.023016

# %%
base_data_2 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_1_(RDKIT)\Baseline_Metrics_dispersity.csv")
base_data_2
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  Polar_dispersity  \
# 0    156        1         23         23       0.00010          0.303887
# 1    156        1         23          4       0.00010          0.371058
# 2    156        1          4         23       0.00010          0.315315
# 3    156        1         23         23       0.00001          0.558824
# 4    156        2         23         23       0.00010          0.391304
# 5    156        2         23         23       0.00001          0.385496
# 6    159        1         23         23       0.00010          0.000000
# 7    159        1         23         23       0.00001          0.347518
# 8    159        2         23         23       0.00010          0.655689
# 9    159        2         23         23       0.00001          0.265517
# 10   159        1         23          4       0.00010          0.139082
# 11   159        1          4         23       0.00010          0.000000
#
#     VSA_EState2_C  Estate_VSA8_C     Estate_VSA8_S  SlogP_VSA4_C  \
# 0        6.492710     131.615783          0.000000      0.000000
# 1        6.492710     131.615783          0.000000      0.000000
# 2        6.492710     131.615783          0.000000      0.000000
# 3        6.492710     131.615783          0.000000      0.000000
# 4        6.492710     131.615783         19.056471      0.000000
# 5        6.492710     131.615783         19.056471      0.000000
# 6       49.043023       0.000000          0.000000     40.457273
# 7       49.043023       0.000000          0.000000     40.457273
# 8       49.043023       0.000000         19.056471     40.457273
# 9       49.043023       0.000000         19.056471     40.457273
# 10      49.043023       0.000000          0.000000     40.457273
# 11      49.043023       0.000000          0.000000     40.457273
#
#     SlogP_VSA4_S  NumAliphaticHeterocycles  NumAliphaticRings  EState_VSA2  \
# 0       0.000000                         2                  2    33.158986
# 1       0.000000                         2                  2    33.158986
# 2       0.000000                         2                  2    33.158986
# 3       0.000000                         2                  2    33.158986
# 4       6.923737                         2                  2    33.158986
# 5       6.923737                         2                  2    33.158986
# 6       0.000000                         3                  3   167.872027
# 7       0.000000                         3                  3   167.872027
# 8       6.923737                         3                  3   167.872027
# 9       6.923737                         3                  3   167.872027
# 10      0.000000                         3                  3   167.872027
# 11      0.000000                         3                  3   167.872027
#
#     NOCount  FpDensityMorgan1  EState_VSA10  fr_ether    TPSA
# 0         6          0.357143     10.213055         4   77.38
# 1         6          0.357143     10.213055         4   77.38
# 2         6          0.357143     10.213055         4   77.38
# 3         6          0.357143     10.213055         4   77.38
# 4         6          0.357143     10.213055         4   77.38
# 5         6          0.357143     10.213055         4   77.38
# 6        22          0.287879     40.457273        10  264.86
# 7        22          0.287879     40.457273        10  264.86
# 8        22          0.287879     40.457273        10  264.86
# 9        22          0.287879     40.457273        10  264.86
# 10       22          0.287879     40.457273        10  264.86
# 11       22          0.287879     40.457273        10  264.86

# %%
res_2 = model_maker(base_data_2,2)
res_2
# Out:
#                 Desc_1 Desc_2 Desc_3 Desc_4      MSE        r2       MAE  \
# 0        VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 1        Estate_VSA8_C      -      -      -  0.10957 -3.291148  0.283507
# 2        Estate_VSA8_S      -      -      -  0.08686 -2.401768  0.260785
# 3         SlogP_VSA4_C      -      -      -  0.10957 -3.291148  0.283507
# 4         SlogP_VSA4_S      -      -      -  0.08686 -2.401768  0.260785
# ...                ...    ...    ...    ...      ...       ...       ...
# 8186     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 8187     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 8188     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 8189     Estate_VSA8_C      -      -      -  0.10957 -3.291148  0.283507
# 8190     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
#
#             C1   C2   C3   C4
# 0     0.000846  0.0  0.0  0.0
# 1    -0.000273  0.0  0.0  0.0
# 2     0.002952  0.0  0.0  0.0
# 3     0.000890  0.0  0.0  0.0
# 4     0.008124  0.0  0.0  0.0
# ...        ...  ...  ...  ...
# 8186  0.000846  0.0  0.0  0.0
# 8187  0.000846  0.0  0.0  0.0
# 8188  0.000846  0.0  0.0  0.0
# 8189 -0.000273  0.0  0.0  0.0
# 8190  0.000846  0.0  0.0  0.0
#
# [8191 rows x 11 columns]

# %%
res_2.to_csv("Results_RDKIT_Dispersity.csv", index = False)

# %% [markdown]
# ----

# %% [markdown]
# # Metric 3 = Ratio of Sphere vs Substance area
#
# 20 relations

# %%
M3_RD_Var = p_val_df_significant[p_val_df_significant['Synthesis_Metric']=='Area_Sphere_Substance'].reset_index(drop = True)

# %%
M3_RD_Var[M3_RD_Var['P_Value']>=0.0225]
# Out:
#                 RD_KIT_Desc       Synthesis_Metric   P_Value
# 0               VSA_EState2  Area_Sphere_Substance  0.048817
# 1               EState_VSA8  Area_Sphere_Substance  0.044045
# 2                SlogP_VSA4  Area_Sphere_Substance  0.041731
# 3               EState_VSA2  Area_Sphere_Substance  0.034603
# 4              EState_VSA10  Area_Sphere_Substance  0.029332
# 5                   NOCount  Area_Sphere_Substance  0.029227
# 6         NumAliphaticRings  Area_Sphere_Substance  0.029113
# 7  NumAliphaticHeterocycles  Area_Sphere_Substance  0.029113
# 8                      TPSA  Area_Sphere_Substance  0.022936

# %%
base_data_3 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_1_(RDKIT)\Baseline_Metrics_Ratio_Sphere-substance.csv")
base_data_3
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  Area_Sphere_Substance  \
# 0    156        1         23         23       0.00010                 0.4424
# 1    156        1         23          4       0.00010                 0.4434
# 2    156        1          4         23       0.00010                 0.1225
# 3    156        1         23         23       0.00001                 0.3281
# 4    156        2         23         23       0.00010                 0.4510
# 5    156        2         23         23       0.00001                 0.0391
# 6    159        1         23         23       0.00010                 0.0000
# 7    159        1         23         23       0.00001                 0.4323
# 8    159        2         23         23       0.00010                 0.2474
# 9    159        2         23         23       0.00001                 0.2629
# 10   159        1         23          4       0.00010                 0.2474
# 11   159        1          4         23       0.00010                 0.0000
#
#     VSA_EState2  Estate_VSA8_C  Estate_VSA8_S  SlogP_VSA4_C  SlogP_VSA4_S  \
# 0      6.492710     131.615783       0.000000      0.000000      0.000000
# 1      6.492710     131.615783       0.000000      0.000000      0.000000
# 2      6.492710     131.615783       0.000000      0.000000      0.000000
# 3      6.492710     131.615783       0.000000      0.000000      0.000000
# 4      6.492710     131.615783      19.056471      0.000000      6.923737
# 5      6.492710     131.615783      19.056471      0.000000      6.923737
# 6     49.043023       0.000000       0.000000     40.457273      0.000000
# 7     49.043023       0.000000       0.000000     40.457273      0.000000
# 8     49.043023       0.000000      19.056471     40.457273      6.923737
# 9     49.043023       0.000000      19.056471     40.457273      6.923737
# 10    49.043023       0.000000       0.000000     40.457273      0.000000
# 11    49.043023       0.000000       0.000000     40.457273      0.000000
#
#     EState_VSA2  EState_VSA10  NOCount  NumAliphaticHeterocycles  \
# 0     33.158986     10.213055        6                         2
# 1     33.158986     10.213055        6                         2
# 2     33.158986     10.213055        6                         2
# 3     33.158986     10.213055        6                         2
# 4     33.158986     10.213055        6                         2
# 5     33.158986     10.213055        6                         2
# 6    167.872027     40.457273       22                         3
# 7    167.872027     40.457273       22                         3
# 8    167.872027     40.457273       22                         3
# 9    167.872027     40.457273       22                         3
# 10   167.872027     40.457273       22                         3
# 11   167.872027     40.457273       22                         3
#
#     NumAliphaticRings    TPSA
# 0                   2   77.38
# 1                   2   77.38
# 2                   2   77.38
# 3                   2   77.38
# 4                   2   77.38
# 5                   2   77.38
# 6                   3  264.86
# 7                   3  264.86
# 8                   3  264.86
# 9                   3  264.86
# 10                  3  264.86
# 11                  3  264.86

# %%
res_3 = model_maker(base_data_3,3)
res_3
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 2047/2047 [00:21<00:00, 96.46it/s]
#              Desc_1 Desc_2 Desc_3 Desc_4       MSE        r2       MAE  \
# 0       VSA_EState2      -      -      -  0.058212 -0.632095  0.217775
# 1     Estate_VSA8_C      -      -      -  0.058212 -0.632095  0.217775
# 2     Estate_VSA8_S      -      -      -  0.083331 -1.336381  0.270422
# 3      SlogP_VSA4_C      -      -      -  0.058212 -0.632095  0.217775
# 4      SlogP_VSA4_S      -      -      -  0.083331 -1.336381  0.270422
# ...             ...    ...    ...    ...       ...       ...       ...
# 2042    VSA_EState2      -      -      -  0.058212 -0.632095  0.217775
# 2043    VSA_EState2      -      -      -  0.058212 -0.632095  0.217775
# 2044    VSA_EState2      -      -      -  0.058212 -0.632095  0.217775
# 2045  Estate_VSA8_C      -      -      -  0.058212 -0.632095  0.217775
# 2046    VSA_EState2      -      -      -  0.058212 -0.632095  0.217775
#
#             C1   C2   C3   C4
# 0     0.000919  0.0  0.0  0.0
# 1    -0.000297  0.0  0.0  0.0
# 2    -0.008953  0.0  0.0  0.0
# 3     0.000966  0.0  0.0  0.0
# 4    -0.024641  0.0  0.0  0.0
# ...        ...  ...  ...  ...
# 2042  0.000919  0.0  0.0  0.0
# 2043  0.000919  0.0  0.0  0.0
# 2044  0.000919  0.0  0.0  0.0
# 2045 -0.000297  0.0  0.0  0.0
# 2046  0.000919  0.0  0.0  0.0
#
# [2047 rows x 11 columns]

# %%
res_3.to_csv("Results_RDKIT_Ratio_Sphere_Substance.csv", index = False)

# %% [markdown]
# --------

# %% [markdown]
# # PHASE 2: Synthesis Conditions versus Metrics

# %% [markdown]
# # Mean Particle Size

# %%
base_data_4 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_2_(Synthesis_Conditions)\Source_Data\Baseline_Metrics_MPS.csv")
base_data_4
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  \
# 0    156        1         23         23       0.00010
# 1    156        1         23          4       0.00010
# 2    156        1          4         23       0.00010
# 3    156        1         23         23       0.00001
# 4    156        2         23         23       0.00010
# 5    156        2         23         23       0.00001
# 6    159        1         23         23       0.00010
# 7    159        1         23         23       0.00001
# 8    159        2         23         23       0.00010
# 9    159        2         23         23       0.00001
# 10   159        1         23          4       0.00010
# 11   159        1          4         23       0.00010
#
#     mean_particle_size_(mps)  Comp.1  T of comp.1  T of solv.1  hydrophilic  \
# 0                 566.363793     156           23           23    1074.3192
# 1                 538.820596     156           23            4    1074.3192
# 2                 221.955591     156            4           23    1074.3192
# 3                 272.233927     156           23           23    1074.3192
# 4                 551.931930     156           23           23    1068.2255
# 5                 262.359462     156           23           23    1068.2255
# 6                   0.000000     159           23           23    3387.1829
# 7                 423.373199     159           23           23    3387.1829
# 8                 333.662212     159           23           23    3435.9498
# 9                 290.411224     159           23           23    3435.9498
# 10                703.277095     159           23            4    3387.1829
# 11                  0.000000     159            4           23    3387.1829
#
#     hydrophilic_section  hydrophbic_section  Conc of comp.1
# 0              0.578597            0.549443         0.00010
# 1              0.578597            0.549443         0.00010
# 2              0.578597            0.549443         0.00010
# 3              0.578597            0.549443         0.00001
# 4              0.590875            0.551821         0.00010
# 5              0.590875            0.551821         0.00001
# 6              0.433544            0.509058         0.00010
# 7              0.433544            0.509058         0.00001
# 8              0.433292            0.516996         0.00010
# 9              0.433292            0.516996         0.00001
# 10             0.433544            0.509058         0.00010
# 11             0.433544            0.509058         0.00010

# %%
res_4 = model_maker(base_data_4,1)
res_4
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 127/127 [00:00<00:00, 153.78it/s]
#                   Desc_1               Desc_2               Desc_3  \
# 0                 Comp.1                    -                    -
# 1            T of comp.1                    -                    -
# 2            T of solv.1                    -                    -
# 3            hydrophilic                    -                    -
# 4    hydrophilic_section                    -                    -
# 5     hydrophbic_section                    -                    -
# 6         Conc of comp.1                    -                    -
# 7                 Comp.1          T of comp.1                    -
# 8                 Comp.1          T of solv.1                    -
# 9                 Comp.1          hydrophilic                    -
# 10                Comp.1  hydrophilic_section                    -
# 11                Comp.1   hydrophbic_section                    -
# 12                Comp.1       Conc of comp.1                    -
# 13           T of comp.1          T of solv.1                    -
# 14           T of comp.1          hydrophilic                    -
# 15           T of comp.1  hydrophilic_section                    -
# 16           T of comp.1   hydrophbic_section                    -
# 17           T of comp.1       Conc of comp.1                    -
# 18           T of solv.1          hydrophilic                    -
# 19           T of solv.1  hydrophilic_section                    -
# 20           T of solv.1   hydrophbic_section                    -
# 21           T of solv.1       Conc of comp.1                    -
# 22           hydrophilic  hydrophilic_section                    -
# 23           hydrophilic   hydrophbic_section                    -
# 24           hydrophilic       Conc of comp.1                    -
# 25   hydrophilic_section   hydrophbic_section                    -
# 26   hydrophilic_section       Conc of comp.1                    -
# 27    hydrophbic_section       Conc of comp.1                    -
# 28                Comp.1          T of comp.1          T of solv.1
# 29                Comp.1          T of comp.1          hydrophilic
# 30                Comp.1          T of comp.1  hydrophilic_section
# 31                Comp.1          T of comp.1   hydrophbic_section
# 32                Comp.1          T of comp.1       Conc of comp.1
# 33                Comp.1          T of solv.1          hydrophilic
# 34                Comp.1          T of solv.1  hydrophilic_section
# 35                Comp.1          T of solv.1   hydrophbic_section
# 36                Comp.1          T of solv.1       Conc of comp.1
# 37                Comp.1          hydrophilic  hydrophilic_section
# 38                Comp.1          hydrophilic   hydrophbic_section
# 39                Comp.1          hydrophilic       Conc of comp.1
# 40                Comp.1  hydrophilic_section   hydrophbic_section
# 41                Comp.1  hydrophilic_section       Conc of comp.1
# 42                Comp.1   hydrophbic_section       Conc of comp.1
# 43           T of comp.1          T of solv.1          hydrophilic
# 44           T of comp.1          T of solv.1  hydrophilic_section
# 45           T of comp.1          T of solv.1   hydrophbic_section
# 46           T of comp.1          T of solv.1       Conc of comp.1
# 47           T of comp.1          hydrophilic  hydrophilic_section
# 48           T of comp.1          hydrophilic   hydrophbic_section
# 49           T of comp.1          hydrophilic       Conc of comp.1
# 50           T of comp.1  hydrophilic_section   hydrophbic_section
# 51           T of comp.1  hydrophilic_section       Conc of comp.1
# 52           T of comp.1   hydrophbic_section       Conc of comp.1
# 53           T of solv.1          hydrophilic  hydrophilic_section
# 54           T of solv.1          hydrophilic   hydrophbic_section
# 55           T of solv.1          hydrophilic       Conc of comp.1
# 56           T of solv.1  hydrophilic_section   hydrophbic_section
# 57           T of solv.1  hydrophilic_section       Conc of comp.1
# 58           T of solv.1   hydrophbic_section       Conc of comp.1
# 59           hydrophilic  hydrophilic_section   hydrophbic_section
# 60           hydrophilic  hydrophilic_section       Conc of comp.1
# 61           hydrophilic   hydrophbic_section       Conc of comp.1
# 62   hydrophilic_section   hydrophbic_section       Conc of comp.1
# 63                Comp.1          T of comp.1          T of solv.1
# 64                Comp.1          T of comp.1          T of solv.1
# 65                Comp.1          T of comp.1          T of solv.1
# 66                Comp.1          T of comp.1          T of solv.1
# 67                Comp.1          T of comp.1          hydrophilic
# 68                Comp.1          T of comp.1          hydrophilic
# 69                Comp.1          T of comp.1          hydrophilic
# 70                Comp.1          T of comp.1  hydrophilic_section
# 71                Comp.1          T of comp.1  hydrophilic_section
# 72                Comp.1          T of comp.1   hydrophbic_section
# 73                Comp.1          T of solv.1          hydrophilic
# 74                Comp.1          T of solv.1          hydrophilic
# 75                Comp.1          T of solv.1          hydrophilic
# 76                Comp.1          T of solv.1  hydrophilic_section
# 77                Comp.1          T of solv.1  hydrophilic_section
# 78                Comp.1          T of solv.1   hydrophbic_section
# 79                Comp.1          hydrophilic  hydrophilic_section
# 80                Comp.1          hydrophilic  hydrophilic_section
# 81                Comp.1          hydrophilic   hydrophbic_section
# 82                Comp.1  hydrophilic_section   hydrophbic_section
# 83           T of comp.1          T of solv.1          hydrophilic
# 84           T of comp.1          T of solv.1          hydrophilic
# 85           T of comp.1          T of solv.1          hydrophilic
# 86           T of comp.1          T of solv.1  hydrophilic_section
# 87           T of comp.1          T of solv.1  hydrophilic_section
# 88           T of comp.1          T of solv.1   hydrophbic_section
# 89           T of comp.1          hydrophilic  hydrophilic_section
# 90           T of comp.1          hydrophilic  hydrophilic_section
# 91           T of comp.1          hydrophilic   hydrophbic_section
# 92           T of comp.1  hydrophilic_section   hydrophbic_section
# 93           T of solv.1          hydrophilic  hydrophilic_section
# 94           T of solv.1          hydrophilic  hydrophilic_section
# 95           T of solv.1          hydrophilic   hydrophbic_section
# 96           T of solv.1  hydrophilic_section   hydrophbic_section
# 97           hydrophilic  hydrophilic_section   hydrophbic_section
# 98                Comp.1                    -                    -
# 99                Comp.1                    -                    -
# 100               Comp.1                    -                    -
# 101               Comp.1                    -                    -
# 102               Comp.1                    -                    -
# 103               Comp.1                    -                    -
# 104               Comp.1                    -                    -
# 105               Comp.1                    -                    -
# 106               Comp.1                    -                    -
# 107               Comp.1                    -                    -
# 108               Comp.1                    -                    -
# 109               Comp.1                    -                    -
# 110               Comp.1                    -                    -
# 111               Comp.1                    -                    -
# 112               Comp.1                    -                    -
# 113          T of comp.1                    -                    -
# 114          T of comp.1                    -                    -
# 115          T of comp.1                    -                    -
# 116          T of comp.1                    -                    -
# 117          T of comp.1                    -                    -
# 118          T of solv.1                    -                    -
# 119               Comp.1                    -                    -
# 120               Comp.1                    -                    -
# 121               Comp.1                    -                    -
# 122               Comp.1                    -                    -
# 123               Comp.1                    -                    -
# 124               Comp.1                    -                    -
# 125          T of comp.1                    -                    -
# 126               Comp.1                    -                    -
#
#                   Desc_4            MSE        r2         MAE            C1  \
# 0                      -  100366.884089  0.009554  308.002807 -7.732599e+00
# 1                      -   81720.547159  0.193561  273.318854  8.522822e+00
# 2                      -   75469.375164  0.255249  263.752800 -1.053673e+01
# 3                      -  100325.213872  0.009965  307.906416 -1.016981e-02
# 4                      -  100954.916946  0.003751  308.918998  1.241526e+02
# 5                      -  101922.231983 -0.005795  310.723898  2.879483e+02
# 6                      -  111616.639484 -0.101462  313.802256  1.145623e+06
# 7                      -   73361.183191  0.276053  251.606151 -2.026519e+01
# 8                      -   78516.857514  0.225176  266.384327  6.140228e+00
# 9                      -  112447.212461 -0.109658  320.619388  1.420629e+03
# 10                     -  112725.646028 -0.112406  334.646325 -5.511565e+02
# 11                     -  127462.001453 -0.257828  340.884575 -2.245111e+02
# 12                     -  112640.948470 -0.111570  314.953282  1.534701e+00
# 13                     -   60526.477848  0.402709  234.586005  7.163774e+00
# 14                     -   73349.608132  0.276167  251.561323  9.907065e+00
# 15                     -   74036.051784  0.269393  253.643544  9.673040e+00
# 16                     -   74571.678248  0.264108  255.410654  9.487316e+00
# 17                     -   83637.374958  0.174645  249.387271  1.356105e+01
# 18                     -   78315.660023  0.227161  266.220574 -1.093360e+01
# 19                     -   79246.326344  0.217977  267.276913 -1.100008e+01
# 20                     -   82109.931776  0.189718  269.664121 -1.118866e+01
# 21                     -   84612.679347  0.165020  272.595574 -8.675091e+00
# 22                     -  119546.472723 -0.179715  344.404016 -8.160028e-01
# 23                     -  126574.366936 -0.249068  339.405698 -2.586285e-01
# 24                     -  112352.328752 -0.108722  314.636623  1.439210e-03
# 25                     -  115367.651142 -0.138478  324.006263  3.091238e+03
# 26                     -  113118.102311 -0.116278  315.579313 -4.518015e+01
# 27                     -  117217.124423 -0.156729  319.834946 -5.642953e+02
# 28                     -   57751.340609  0.430095  230.126793 -5.945616e+00
# 29                     -   79642.785699  0.214065  264.026717  1.298831e+03
# 30                     -   85589.090412  0.155385  275.275464 -8.040714e+02
# 100  0.000000e+00  0.000000e+00  0.000000e+00
# 101  0.000000e+00  0.000000e+00  0.000000e+00
# 102  0.000000e+00  0.000000e+00  0.000000e+00
# 103  0.000000e+00  0.000000e+00  0.000000e+00
# 104  0.000000e+00  0.000000e+00  0.000000e+00
# 105  0.000000e+00  0.000000e+00  0.000000e+00
# 106  0.000000e+00  0.000000e+00  0.000000e+00
# 107  0.000000e+00  0.000000e+00  0.000000e+00
# 108  0.000000e+00  0.000000e+00  0.000000e+00
# 109  0.000000e+00  0.000000e+00  0.000000e+00
# 110  0.000000e+00  0.000000e+00  0.000000e+00
# 111  0.000000e+00  0.000000e+00  0.000000e+00
# 112  0.000000e+00  0.000000e+00  0.000000e+00
# 113  0.000000e+00  0.000000e+00  0.000000e+00
# 114  0.000000e+00  0.000000e+00  0.000000e+00
# 115  0.000000e+00  0.000000e+00  0.000000e+00
# 116  0.000000e+00  0.000000e+00  0.000000e+00
# 117  0.000000e+00  0.000000e+00  0.000000e+00
# 118  0.000000e+00  0.000000e+00  0.000000e+00
# 119  0.000000e+00  0.000000e+00  0.000000e+00
# 120  0.000000e+00  0.000000e+00  0.000000e+00
# 121  0.000000e+00  0.000000e+00  0.000000e+00
# 122  0.000000e+00  0.000000e+00  0.000000e+00
# 123  0.000000e+00  0.000000e+00  0.000000e+00
# 124  0.000000e+00  0.000000e+00  0.000000e+00
# 125  0.000000e+00  0.000000e+00  0.000000e+00
# 126  0.000000e+00  0.000000e+00  0.000000e+00

# %%
res_4.to_csv("Results_Synthesis_Conditions-MPS.csv", index = False)

# %% [markdown]
# ----

# %% [markdown]
# # Metric 2: Poly Dispersity

# %%
base_data_5 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_2_(Synthesis_Conditions)\Source_Data\Baseline_Metrics_Polar_Dispersity.csv")
base_data_5
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  Polar_dispersity  \
# 0    156        1         23         23       0.00010          0.303887
# 1    156        1         23          4       0.00010          0.371058
# 2    156        1          4         23       0.00010          0.315315
# 3    156        1         23         23       0.00001          0.558824
# 4    156        2         23         23       0.00010          0.391304
# 5    156        2         23         23       0.00001          0.385496
# 6    159        1         23         23       0.00010          0.000000
# 7    159        1         23         23       0.00001          0.347518
# 8    159        2         23         23       0.00010          0.655689
# 9    159        2         23         23       0.00001          0.265517
# 10   159        1         23          4       0.00010          0.139082
# 11   159        1          4         23       0.00010          0.000000
#
#     hydrophilic_section  hydrophbic_section  Full_molecule  hydrophilic
# 0              0.578597            0.549443       0.584598    1074.3192
# 1              0.578597            0.549443       0.584598    1074.3192
# 2              0.578597            0.549443       0.584598    1074.3192
# 3              0.578597            0.549443       0.584598    1074.3192
# 4              0.590875            0.551821       0.587235    1068.2255
# 5              0.590875            0.551821       0.587235    1068.2255
# 6              0.433544            0.509058       0.670052    3387.1829
# 7              0.433544            0.509058       0.670052    3387.1829
# 8              0.433292            0.516996       0.651590    3435.9498
# 9              0.433292            0.516996       0.651590    3435.9498
# 10             0.433544            0.509058       0.670052    3387.1829
# 11             0.433544            0.509058       0.670052    3387.1829

# %%
res_5 = model_maker(base_data_5,2)
res_5
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 148.32it/s]
#                  Desc_1              Desc_2         Desc_3       Desc_4  \
# 0   hydrophilic_section                   -              -            -
# 1    hydrophbic_section                   -              -            -
# 2         Full_molecule                   -              -            -
# 3           hydrophilic                   -              -            -
# 4   hydrophilic_section  hydrophbic_section              -            -
# 5   hydrophilic_section       Full_molecule              -            -
# 6   hydrophilic_section         hydrophilic              -            -
# 7    hydrophbic_section       Full_molecule              -            -
# 8    hydrophbic_section         hydrophilic              -            -
# 9         Full_molecule         hydrophilic              -            -
# 10  hydrophilic_section  hydrophbic_section  Full_molecule            -
# 11  hydrophilic_section  hydrophbic_section    hydrophilic            -
# 12  hydrophilic_section       Full_molecule    hydrophilic            -
# 13   hydrophbic_section       Full_molecule    hydrophilic            -
# 14  hydrophilic_section  hydrophbic_section  Full_molecule  hydrophilic
#
#          MSE        r2       MAE         C1         C2        C3        C4
# 0   0.109562 -3.290855  0.284090  -0.243892   0.000000  0.000000  0.000000
# 1   0.108466 -3.247942  0.281513  -0.746411   0.000000  0.000000  0.000000
# 2   0.108150 -3.235544  0.280627   0.346329   0.000000  0.000000  0.000000
# 3   0.109576 -3.291398  0.283612   0.000016   0.000000  0.000000  0.000000
# 4   0.071440 -1.797845  0.229404  -3.620693  14.029937  0.000000  0.000000
# 5   0.078578 -2.077421  0.246967  -2.591421  -4.794946  0.000000  0.000000
# 6   0.107857 -3.224063  0.282816   1.645953   0.000119  0.000000  0.000000
# 7   0.105448 -3.129742  0.282798  -8.314590  -3.708684  0.000000  0.000000
# 8   0.074123 -1.902944  0.234786  11.895454   0.000196  0.000000  0.000000
# 9   0.072029 -1.820931  0.231275  -5.506838   0.000186  0.000000  0.000000
# 10  0.071254 -1.790571  0.227320  -3.734593  17.114854  1.283936  0.000000
# 11  0.071254 -1.790571  0.227320  -2.803693  13.857299  0.000049  0.000000
# 12  0.071254 -1.790571  0.227320   1.156261  -5.461731  0.000257  0.000000
# 13  0.071254 -1.790571  0.227320   4.046171  -3.866969  0.000196  0.000000
# 14  0.071254 -1.790571  0.227320   0.582627   2.007351 -4.670551  0.000227

# %%
res_5.to_csv("Results_Synthesis_Conditions-Dispersity.csv", index = False)

# %% [markdown]
# -------

# %% [markdown]
# # Metric 3: Ratio Sphere Substance

# %%
base_data_6 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_2_(Synthesis_Conditions)\Source_Data\Baseline_Metrics_Ratio_Sphere_Substance.csv")
base_data_6
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  Area_Sphere_Substance  \
# 0    156        1         23         23       0.00010                 0.4424
# 1    156        1         23          4       0.00010                 0.4434
# 2    156        1          4         23       0.00010                 0.1225
# 3    156        1         23         23       0.00001                 0.3281
# 4    156        2         23         23       0.00010                 0.4510
# 5    156        2         23         23       0.00001                 0.0391
# 6    159        1         23         23       0.00010                 0.0000
# 7    159        1         23         23       0.00001                 0.4323
# 8    159        2         23         23       0.00010                 0.2474
# 9    159        2         23         23       0.00001                 0.2629
# 10   159        1         23          4       0.00010                 0.2474
# 11   159        1          4         23       0.00010                 0.0000
#
#     hydrophilic_section  hydrophbic_section  hydrophilic
# 0              0.578597            0.549443    1074.3192
# 1              0.578597            0.549443    1074.3192
# 2              0.578597            0.549443    1074.3192
# 3              0.578597            0.549443    1074.3192
# 4              0.590875            0.551821    1068.2255
# 5              0.590875            0.551821    1068.2255
# 6              0.433544            0.509058    3387.1829
# 7              0.433544            0.509058    3387.1829
# 8              0.433292            0.516996    3435.9498
# 9              0.433292            0.516996    3435.9498
# 10             0.433544            0.509058    3387.1829
# 11             0.433544            0.509058    3387.1829

# %%
res_6 = model_maker(base_data_6,3)
res_6
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 144.16it/s]
#                 Desc_1              Desc_2       Desc_3 Desc_4       MSE  \
# 0  hydrophilic_section                   -            -      -  0.061078
# 1   hydrophbic_section                   -            -      -  0.067348
# 2          hydrophilic                   -            -      -  0.057789
# 3  hydrophilic_section  hydrophbic_section            -      -  0.104011
# 4  hydrophilic_section         hydrophilic            -      -  0.114988
# 5   hydrophbic_section         hydrophilic            -      -  0.142455
# 6  hydrophilic_section  hydrophbic_section  hydrophilic      -  0.144404
#
#          r2       MAE         C1         C2        C3   C4
# 0 -0.712471  0.224297  -0.333913   0.000000  0.000000  0.0
# 1 -0.888264  0.237293  -1.697678   0.000000  0.000000  0.0
# 2 -0.620240  0.216843   0.000016   0.000000  0.000000  0.0
# 3 -1.916176  0.297880   4.209775 -18.878116  0.000000  0.0
# 4 -2.223951  0.317352 -26.508425  -0.001652  0.000000  0.0
# 5 -2.994062  0.356180 -28.851875  -0.000420  0.000000  0.0
# 6 -3.048699  0.365350 -22.241321 -13.288818 -0.001584  0.0

# %%
res_6.to_csv("Results_Synthesis_Conditions-Ratio_Sphere_Substance.csv", index = False)

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 3: Hybrid Model

# %%
base_data_7 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_3_(RD-desc_SYnthesis)\Data_Synthesis_MPS.csv")
base_data_7
# Out:
#     Comp     Solvent  T of comp  T of solv  Conc of comp  \
# 0    156  Chloroform         23         23       0.00010
# 1    156  Chloroform         23          4       0.00010
# 2    156  Chloroform          4         23       0.00010
# 3    156  Chloroform         23         23       0.00001
# 4    156     Toluene         23         23       0.00010
# 5    156     Toluene         23         23       0.00001
# 6    159  Chloroform         23         23       0.00010
# 7    159  Chloroform         23         23       0.00001
# 8    159     Toluene         23         23       0.00010
# 9    159     Toluene         23         23       0.00001
# 10   159  Chloroform         23          4       0.00010
# 11   159  Chloroform          4         23       0.00010
#
#     mean_particle_size_(mps)  TPSA_C  PEOE_VSA6_C  PEOE_VSA6_S  Comp.1  \
# 0                        566   77.38   130.132386    34.802820     156
# 1                        539   77.38   130.132386    34.802820     156
# 2                        222   77.38   130.132386    34.802820     156
# 3                        272   77.38   130.132386    34.802820     156
# 4                        552   77.38   130.132386    35.895287     156
# 5                        262   77.38   130.132386    35.895287     156
# 6                          0  264.86    47.047540    34.802820     159
# 7                        423  264.86    47.047540    34.802820     159
# 8                        334  264.86    47.047540    35.895287     159
# 9                        290  264.86    47.047540    35.895287     159
# 10                       719  264.86    47.047540    34.802820     159
# 11                         0  264.86    47.047540    34.802820     159
#
#     T of comp.1  T of solv.1  hydrophilic  hydrophilic_section  \
# 0            23           23    1074.3192             0.578597
# 1            23            4    1074.3192             0.578597
# 2             4           23    1074.3192             0.578597
# 3            23           23    1074.3192             0.578597
# 4            23           23    1068.2255             0.590875
# 5            23           23    1068.2255             0.590875
# 6            23           23    3387.1829             0.433544
# 7            23           23    3387.1829             0.433544
# 8            23           23    3435.9498             0.433292
# 9            23           23    3435.9498             0.433292
# 10           23            4    3387.1829             0.433544
# 11            4           23    3387.1829             0.433544
#
#     hydrophbic_section  Conc of comp.1
# 0             0.549443         0.00010
# 1             0.549443         0.00010
# 2             0.549443         0.00010
# 3             0.549443         0.00001
# 4             0.551821         0.00010
# 5             0.551821         0.00001
# 6             0.509058         0.00010
# 7             0.509058         0.00001
# 8             0.516996         0.00010
# 9             0.516996         0.00001
# 10            0.509058         0.00010
# 11            0.509058         0.00010

# %%
res_7 = model_maker(base_data_7,1)
res_7
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1023/1023 [00:06<00:00, 153.98it/s]
#                    Desc_1               Desc_2               Desc_3  \
# 0                  TPSA_C                    -                    -
# 1             PEOE_VSA6_C                    -                    -
# 2             PEOE_VSA6_S                    -                    -
# 3                  Comp.1                    -                    -
# 4             T of comp.1                    -                    -
# 5             T of solv.1                    -                    -
# 6             hydrophilic                    -                    -
# 7     hydrophilic_section                    -                    -
# 8      hydrophbic_section                    -                    -
# 9          Conc of comp.1                    -                    -
# 10                 TPSA_C          PEOE_VSA6_C                    -
# 11                 TPSA_C          PEOE_VSA6_S                    -
# 12                 TPSA_C               Comp.1                    -
# 13                 TPSA_C          T of comp.1                    -
# 14                 TPSA_C          T of solv.1                    -
# 15                 TPSA_C          hydrophilic                    -
# 16                 TPSA_C  hydrophilic_section                    -
# 17                 TPSA_C   hydrophbic_section                    -
# 18                 TPSA_C       Conc of comp.1                    -
# 19            PEOE_VSA6_C          PEOE_VSA6_S                    -
# 20            PEOE_VSA6_C               Comp.1                    -
# 21            PEOE_VSA6_C          T of comp.1                    -
# 22            PEOE_VSA6_C          T of solv.1                    -
# 23            PEOE_VSA6_C          hydrophilic                    -
# 24            PEOE_VSA6_C  hydrophilic_section                    -
# 25            PEOE_VSA6_C   hydrophbic_section                    -
# 26            PEOE_VSA6_C       Conc of comp.1                    -
# 27            PEOE_VSA6_S               Comp.1                    -
# 28            PEOE_VSA6_S          T of comp.1                    -
# 29            PEOE_VSA6_S          T of solv.1                    -
# 30            PEOE_VSA6_S          hydrophilic                    -
# 31            PEOE_VSA6_S  hydrophilic_section                    -
# 32            PEOE_VSA6_S   hydrophbic_section                    -
# 33            PEOE_VSA6_S       Conc of comp.1                    -
# 34                 Comp.1          T of comp.1                    -
# 35                 Comp.1          T of solv.1                    -
# 36                 Comp.1          hydrophilic                    -
# 37                 Comp.1  hydrophilic_section                    -
# 38                 Comp.1   hydrophbic_section                    -
# 39                 Comp.1       Conc of comp.1                    -
# 40            T of comp.1          T of solv.1                    -
# 41            T of comp.1          hydrophilic                    -
# 42            T of comp.1  hydrophilic_section                    -
# 43            T of comp.1   hydrophbic_section                    -
# 44            T of comp.1       Conc of comp.1                    -
# 45            T of solv.1          hydrophilic                    -
# 46            T of solv.1  hydrophilic_section                    -
# 47            T of solv.1   hydrophbic_section                    -
# 48            T of solv.1       Conc of comp.1                    -
# 49            hydrophilic  hydrophilic_section                    -
# 50            hydrophilic   hydrophbic_section                    -
# 51            hydrophilic       Conc of comp.1                    -
# 52    hydrophilic_section   hydrophbic_section                    -
# 53    hydrophilic_section       Conc of comp.1                    -
# 54     hydrophbic_section       Conc of comp.1                    -
# 55                 TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 56                 TPSA_C          PEOE_VSA6_C               Comp.1
# 57                 TPSA_C          PEOE_VSA6_C          T of comp.1
# 58                 TPSA_C          PEOE_VSA6_C          T of solv.1
# 59                 TPSA_C          PEOE_VSA6_C          hydrophilic
# 60                 TPSA_C          PEOE_VSA6_C  hydrophilic_section
# 61                 TPSA_C          PEOE_VSA6_C   hydrophbic_section
# 62                 TPSA_C          PEOE_VSA6_C       Conc of comp.1
# 63                 TPSA_C          PEOE_VSA6_S               Comp.1
# 64                 TPSA_C          PEOE_VSA6_S          T of comp.1
# 65                 TPSA_C          PEOE_VSA6_S          T of solv.1
# 66                 TPSA_C          PEOE_VSA6_S          hydrophilic
# 67                 TPSA_C          PEOE_VSA6_S  hydrophilic_section
# 68                 TPSA_C          PEOE_VSA6_S   hydrophbic_section
# 69                 TPSA_C          PEOE_VSA6_S       Conc of comp.1
# 70                 TPSA_C               Comp.1          T of comp.1
# 71                 TPSA_C               Comp.1          T of solv.1
# 72                 TPSA_C               Comp.1          hydrophilic
# 73                 TPSA_C               Comp.1  hydrophilic_section
# 74                 TPSA_C               Comp.1   hydrophbic_section
# 75                 TPSA_C               Comp.1       Conc of comp.1
# 76                 TPSA_C          T of comp.1          T of solv.1
# 77                 TPSA_C          T of comp.1          hydrophilic
# 78                 TPSA_C          T of comp.1  hydrophilic_section
# 79                 TPSA_C          T of comp.1   hydrophbic_section
# 80                 TPSA_C          T of comp.1       Conc of comp.1
# 81                 TPSA_C          T of solv.1          hydrophilic
# 82                 TPSA_C          T of solv.1  hydrophilic_section
# 83                 TPSA_C          T of solv.1   hydrophbic_section
# 84                 TPSA_C          T of solv.1       Conc of comp.1
# 85                 TPSA_C          hydrophilic  hydrophilic_section
# 86                 TPSA_C          hydrophilic   hydrophbic_section
# 87                 TPSA_C          hydrophilic       Conc of comp.1
# 88                 TPSA_C  hydrophilic_section   hydrophbic_section
# 89                 TPSA_C  hydrophilic_section       Conc of comp.1
# 90                 TPSA_C   hydrophbic_section       Conc of comp.1
# 91            PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 92            PEOE_VSA6_C          PEOE_VSA6_S          T of comp.1
# 93            PEOE_VSA6_C          PEOE_VSA6_S          T of solv.1
# 94            PEOE_VSA6_C          PEOE_VSA6_S          hydrophilic
# 95            PEOE_VSA6_C          PEOE_VSA6_S  hydrophilic_section
# 96            PEOE_VSA6_C          PEOE_VSA6_S   hydrophbic_section
# 97            PEOE_VSA6_C          PEOE_VSA6_S       Conc of comp.1
# 98            PEOE_VSA6_C               Comp.1          T of comp.1
# 99            PEOE_VSA6_C               Comp.1          T of solv.1
# 100           PEOE_VSA6_C               Comp.1          hydrophilic
# 101           PEOE_VSA6_C               Comp.1  hydrophilic_section
# 102           PEOE_VSA6_C               Comp.1   hydrophbic_section
# 103           PEOE_VSA6_C               Comp.1       Conc of comp.1
# 104           PEOE_VSA6_C          T of comp.1          T of solv.1
# 105           PEOE_VSA6_C          T of comp.1          hydrophilic
# 106           PEOE_VSA6_C          T of comp.1  hydrophilic_section
# 107           PEOE_VSA6_C          T of comp.1   hydrophbic_section
# 108           PEOE_VSA6_C          T of comp.1       Conc of comp.1
# 109           PEOE_VSA6_C          T of solv.1          hydrophilic
# 110           PEOE_VSA6_C          T of solv.1  hydrophilic_section
# 111           PEOE_VSA6_C          T of solv.1   hydrophbic_section
# 112           PEOE_VSA6_C          T of solv.1       Conc of comp.1
# 113           PEOE_VSA6_C          hydrophilic  hydrophilic_section
# 114           PEOE_VSA6_C          hydrophilic   hydrophbic_section
# 115           PEOE_VSA6_C          hydrophilic       Conc of comp.1
# 116           PEOE_VSA6_C  hydrophilic_section   hydrophbic_section
# 117           PEOE_VSA6_C  hydrophilic_section       Conc of comp.1
# 118           PEOE_VSA6_C   hydrophbic_section       Conc of comp.1
# 119           PEOE_VSA6_S               Comp.1          T of comp.1
# 120           PEOE_VSA6_S               Comp.1          T of solv.1
# 121           PEOE_VSA6_S               Comp.1          hydrophilic
# 122           PEOE_VSA6_S               Comp.1  hydrophilic_section
# 123           PEOE_VSA6_S               Comp.1   hydrophbic_section
# 124           PEOE_VSA6_S               Comp.1       Conc of comp.1
# 125           PEOE_VSA6_S          T of comp.1          T of solv.1
# 126           PEOE_VSA6_S          T of comp.1          hydrophilic
# 127           PEOE_VSA6_S          T of comp.1  hydrophilic_section
# 128           PEOE_VSA6_S          T of comp.1   hydrophbic_section
# 129           PEOE_VSA6_S          T of comp.1       Conc of comp.1
# 130           PEOE_VSA6_S          T of solv.1          hydrophilic
# 131           PEOE_VSA6_S          T of solv.1  hydrophilic_section
# 132           PEOE_VSA6_S          T of solv.1   hydrophbic_section
# 133           PEOE_VSA6_S          T of solv.1       Conc of comp.1
# 134           PEOE_VSA6_S          hydrophilic  hydrophilic_section
# 135           PEOE_VSA6_S          hydrophilic   hydrophbic_section
# 136           PEOE_VSA6_S          hydrophilic       Conc of comp.1
# 137           PEOE_VSA6_S  hydrophilic_section   hydrophbic_section
# 138           PEOE_VSA6_S  hydrophilic_section       Conc of comp.1
# 139           PEOE_VSA6_S   hydrophbic_section       Conc of comp.1
# 140                Comp.1          T of comp.1          T of solv.1
# 141                Comp.1          T of comp.1          hydrophilic
# 142                Comp.1          T of comp.1  hydrophilic_section
# 143                Comp.1          T of comp.1   hydrophbic_section
# 144                Comp.1          T of comp.1       Conc of comp.1
# 145                Comp.1          T of solv.1          hydrophilic
# 146                Comp.1          T of solv.1  hydrophilic_section
# 147                Comp.1          T of solv.1   hydrophbic_section
# 148                Comp.1          T of solv.1       Conc of comp.1
# 149                Comp.1          hydrophilic  hydrophilic_section
# 150                Comp.1          hydrophilic   hydrophbic_section
# 151                Comp.1          hydrophilic       Conc of comp.1
# 152                Comp.1  hydrophilic_section   hydrophbic_section
# 153                Comp.1  hydrophilic_section       Conc of comp.1
# 154                Comp.1   hydrophbic_section       Conc of comp.1
# 155           T of comp.1          T of solv.1          hydrophilic
# 156           T of comp.1          T of solv.1  hydrophilic_section
# 157           T of comp.1          T of solv.1   hydrophbic_section
# 158           T of comp.1          T of solv.1       Conc of comp.1
# 159           T of comp.1          hydrophilic  hydrophilic_section
# 160           T of comp.1          hydrophilic   hydrophbic_section
# 161           T of comp.1          hydrophilic       Conc of comp.1
# 162           T of comp.1  hydrophilic_section   hydrophbic_section
# 163           T of comp.1  hydrophilic_section       Conc of comp.1
# 164           T of comp.1   hydrophbic_section       Conc of comp.1
# 165           T of solv.1          hydrophilic  hydrophilic_section
# 166           T of solv.1          hydrophilic   hydrophbic_section
# 167           T of solv.1          hydrophilic       Conc of comp.1
# 168           T of solv.1  hydrophilic_section   hydrophbic_section
# 169           T of solv.1  hydrophilic_section       Conc of comp.1
# 170           T of solv.1   hydrophbic_section       Conc of comp.1
# 171           hydrophilic  hydrophilic_section   hydrophbic_section
# 172           hydrophilic  hydrophilic_section       Conc of comp.1
# 173           hydrophilic   hydrophbic_section       Conc of comp.1
# 174   hydrophilic_section   hydrophbic_section       Conc of comp.1
# 175                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 176                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 177                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 178                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 179                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 180                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 181                TPSA_C          PEOE_VSA6_C          PEOE_VSA6_S
# 182                TPSA_C          PEOE_VSA6_C               Comp.1
# 183                TPSA_C          PEOE_VSA6_C               Comp.1
# 184                TPSA_C          PEOE_VSA6_C               Comp.1
# 185                TPSA_C          PEOE_VSA6_C               Comp.1
# 186                TPSA_C          PEOE_VSA6_C               Comp.1
# 187                TPSA_C          PEOE_VSA6_C               Comp.1
# 188                TPSA_C          PEOE_VSA6_C          T of comp.1
# 189                TPSA_C          PEOE_VSA6_C          T of comp.1
# 190                TPSA_C          PEOE_VSA6_C          T of comp.1
# 191                TPSA_C          PEOE_VSA6_C          T of comp.1
# 192                TPSA_C          PEOE_VSA6_C          T of comp.1
# 193                TPSA_C          PEOE_VSA6_C          T of solv.1
# 194                TPSA_C          PEOE_VSA6_C          T of solv.1
# 195                TPSA_C          PEOE_VSA6_C          T of solv.1
# 196                TPSA_C          PEOE_VSA6_C          T of solv.1
# 197                TPSA_C          PEOE_VSA6_C          hydrophilic
# 198                TPSA_C          PEOE_VSA6_C          hydrophilic
# 199                TPSA_C          PEOE_VSA6_C          hydrophilic
# 200                TPSA_C          PEOE_VSA6_C  hydrophilic_section
# 201                TPSA_C          PEOE_VSA6_C  hydrophilic_section
# 202                TPSA_C          PEOE_VSA6_C   hydrophbic_section
# 203                TPSA_C          PEOE_VSA6_S               Comp.1
# 204                TPSA_C          PEOE_VSA6_S               Comp.1
# 205                TPSA_C          PEOE_VSA6_S               Comp.1
# 206                TPSA_C          PEOE_VSA6_S               Comp.1
# 207                TPSA_C          PEOE_VSA6_S               Comp.1
# 208                TPSA_C          PEOE_VSA6_S               Comp.1
# 209                TPSA_C          PEOE_VSA6_S          T of comp.1
# 210                TPSA_C          PEOE_VSA6_S          T of comp.1
# 211                TPSA_C          PEOE_VSA6_S          T of comp.1
# 212                TPSA_C          PEOE_VSA6_S          T of comp.1
# 213                TPSA_C          PEOE_VSA6_S          T of comp.1
# 214                TPSA_C          PEOE_VSA6_S          T of solv.1
# 215                TPSA_C          PEOE_VSA6_S          T of solv.1
# 216                TPSA_C          PEOE_VSA6_S          T of solv.1
# 217                TPSA_C          PEOE_VSA6_S          T of solv.1
# 218                TPSA_C          PEOE_VSA6_S          hydrophilic
# 219                TPSA_C          PEOE_VSA6_S          hydrophilic
# 220                TPSA_C          PEOE_VSA6_S          hydrophilic
# 221                TPSA_C          PEOE_VSA6_S  hydrophilic_section
# 222                TPSA_C          PEOE_VSA6_S  hydrophilic_section
# 223                TPSA_C          PEOE_VSA6_S   hydrophbic_section
# 224                TPSA_C               Comp.1          T of comp.1
# 225                TPSA_C               Comp.1          T of comp.1
# 226                TPSA_C               Comp.1          T of comp.1
# 227                TPSA_C               Comp.1          T of comp.1
# 228                TPSA_C               Comp.1          T of comp.1
# 229                TPSA_C               Comp.1          T of solv.1
# 230                TPSA_C               Comp.1          T of solv.1
# 231                TPSA_C               Comp.1          T of solv.1
# 232                TPSA_C               Comp.1          T of solv.1
# 233                TPSA_C               Comp.1          hydrophilic
# 234                TPSA_C               Comp.1          hydrophilic
# 235                TPSA_C               Comp.1          hydrophilic
# 236                TPSA_C               Comp.1  hydrophilic_section
# 237                TPSA_C               Comp.1  hydrophilic_section
# 238                TPSA_C               Comp.1   hydrophbic_section
# 239                TPSA_C          T of comp.1          T of solv.1
# 240                TPSA_C          T of comp.1          T of solv.1
# 241                TPSA_C          T of comp.1          T of solv.1
# 242                TPSA_C          T of comp.1          T of solv.1
# 243                TPSA_C          T of comp.1          hydrophilic
# 244                TPSA_C          T of comp.1          hydrophilic
# 245                TPSA_C          T of comp.1          hydrophilic
# 246                TPSA_C          T of comp.1  hydrophilic_section
# 247                TPSA_C          T of comp.1  hydrophilic_section
# 248                TPSA_C          T of comp.1   hydrophbic_section
# 249                TPSA_C          T of solv.1          hydrophilic
# 250                TPSA_C          T of solv.1          hydrophilic
# 251                TPSA_C          T of solv.1          hydrophilic
# 252                TPSA_C          T of solv.1  hydrophilic_section
# 253                TPSA_C          T of solv.1  hydrophilic_section
# 254                TPSA_C          T of solv.1   hydrophbic_section
# 255                TPSA_C          hydrophilic  hydrophilic_section
# 256                TPSA_C          hydrophilic  hydrophilic_section
# 257                TPSA_C          hydrophilic   hydrophbic_section
# 258                TPSA_C  hydrophilic_section   hydrophbic_section
# 259           PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 260           PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 261           PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 262           PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 263           PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 264           PEOE_VSA6_C          PEOE_VSA6_S               Comp.1
# 265           PEOE_VSA6_C          PEOE_VSA6_S          T of comp.1
# 266           PEOE_VSA6_C          PEOE_VSA6_S          T of comp.1
# 267           PEOE_VSA6_C          PEOE_VSA6_S          T of comp.1
# 268           PEOE_VSA6_C          PEOE_VSA6_S          T of comp.1
# 269           PEOE_VSA6_C          PEOE_VSA6_S          T of comp.1
# 270           PEOE_VSA6_C          PEOE_VSA6_S          T of solv.1
# 271           PEOE_VSA6_C          PEOE_VSA6_S          T of solv.1
# 272           PEOE_VSA6_C          PEOE_VSA6_S          T of solv.1
# 273           PEOE_VSA6_C          PEOE_VSA6_S          T of solv.1
# 274           PEOE_VSA6_C          PEOE_VSA6_S          hydrophilic
# 275           PEOE_VSA6_C          PEOE_VSA6_S          hydrophilic
# 276           PEOE_VSA6_C          PEOE_VSA6_S          hydrophilic
# 277           PEOE_VSA6_C          PEOE_VSA6_S  hydrophilic_section
# 278           PEOE_VSA6_C          PEOE_VSA6_S  hydrophilic_section
# 279           PEOE_VSA6_C          PEOE_VSA6_S   hydrophbic_section
# 280           PEOE_VSA6_C               Comp.1          T of comp.1
# 281           PEOE_VSA6_C               Comp.1          T of comp.1
# 282           PEOE_VSA6_C               Comp.1          T of comp.1
# 283           PEOE_VSA6_C               Comp.1          T of comp.1
# 284           PEOE_VSA6_C               Comp.1          T of comp.1
# 285           PEOE_VSA6_C               Comp.1          T of solv.1
# 286           PEOE_VSA6_C               Comp.1          T of solv.1
# 287           PEOE_VSA6_C               Comp.1          T of solv.1
# 288           PEOE_VSA6_C               Comp.1          T of solv.1
# 289           PEOE_VSA6_C               Comp.1          hydrophilic
# 290           PEOE_VSA6_C               Comp.1          hydrophilic
# 291           PEOE_VSA6_C               Comp.1          hydrophilic
# 292           PEOE_VSA6_C               Comp.1  hydrophilic_section
# 293           PEOE_VSA6_C               Comp.1  hydrophilic_section
# 294           PEOE_VSA6_C               Comp.1   hydrophbic_section
# 295           PEOE_VSA6_C          T of comp.1          T of solv.1
# 296           PEOE_VSA6_C          T of comp.1          T of solv.1
# 297           PEOE_VSA6_C          T of comp.1          T of solv.1
# 298           PEOE_VSA6_C          T of comp.1          T of solv.1
# 299           PEOE_VSA6_C          T of comp.1          hydrophilic
# 300           PEOE_VSA6_C          T of comp.1          hydrophilic
# 301           PEOE_VSA6_C          T of comp.1          hydrophilic
# 302           PEOE_VSA6_C          T of comp.1  hydrophilic_section
# 303           PEOE_VSA6_C          T of comp.1  hydrophilic_section
# 304           PEOE_VSA6_C          T of comp.1   hydrophbic_section
# 305           PEOE_VSA6_C          T of solv.1          hydrophilic
# 306           PEOE_VSA6_C          T of solv.1          hydrophilic
# 307           PEOE_VSA6_C          T of solv.1          hydrophilic
# 308           PEOE_VSA6_C          T of solv.1  hydrophilic_section
# 309           PEOE_VSA6_C          T of solv.1  hydrophilic_section
# 310           PEOE_VSA6_C          T of solv.1   hydrophbic_section
# 311           PEOE_VSA6_C          hydrophilic  hydrophilic_section
# 312           PEOE_VSA6_C          hydrophilic  hydrophilic_section
# 313           PEOE_VSA6_C          hydrophilic   hydrophbic_section
# 314           PEOE_VSA6_C  hydrophilic_section   hydrophbic_section
# 315           PEOE_VSA6_S               Comp.1          T of comp.1
# 316           PEOE_VSA6_S               Comp.1          T of comp.1
# 317           PEOE_VSA6_S               Comp.1          T of comp.1
# 318           PEOE_VSA6_S               Comp.1          T of comp.1
# 319           PEOE_VSA6_S               Comp.1          T of comp.1
# 320           PEOE_VSA6_S               Comp.1          T of solv.1
# 321           PEOE_VSA6_S               Comp.1          T of solv.1
# 322           PEOE_VSA6_S               Comp.1          T of solv.1
# 323           PEOE_VSA6_S               Comp.1          T of solv.1
# 324           PEOE_VSA6_S               Comp.1          hydrophilic
# 325           PEOE_VSA6_S               Comp.1          hydrophilic
# 326           PEOE_VSA6_S               Comp.1          hydrophilic
# 327           PEOE_VSA6_S               Comp.1  hydrophilic_section
# 328           PEOE_VSA6_S               Comp.1  hydrophilic_section
# 329           PEOE_VSA6_S               Comp.1   hydrophbic_section
# 330           PEOE_VSA6_S          T of comp.1          T of solv.1
# 331           PEOE_VSA6_S          T of comp.1          T of solv.1
# 332           PEOE_VSA6_S          T of comp.1          T of solv.1
# 333           PEOE_VSA6_S          T of comp.1          T of solv.1
# 334           PEOE_VSA6_S          T of comp.1          hydrophilic
# 335           PEOE_VSA6_S          T of comp.1          hydrophilic
# 336           PEOE_VSA6_S          T of comp.1          hydrophilic
# 337           PEOE_VSA6_S          T of comp.1  hydrophilic_section
# 338           PEOE_VSA6_S          T of comp.1  hydrophilic_section
# 339           PEOE_VSA6_S          T of comp.1   hydrophbic_section
# 340           PEOE_VSA6_S          T of solv.1          hydrophilic
# 341           PEOE_VSA6_S          T of solv.1          hydrophilic
# 342           PEOE_VSA6_S          T of solv.1          hydrophilic
# 343           PEOE_VSA6_S          T of solv.1  hydrophilic_section
# 344           PEOE_VSA6_S          T of solv.1  hydrophilic_section
# 345           PEOE_VSA6_S          T of solv.1   hydrophbic_section
# 346           PEOE_VSA6_S          hydrophilic  hydrophilic_section
# 347           PEOE_VSA6_S          hydrophilic  hydrophilic_section
# 348           PEOE_VSA6_S          hydrophilic   hydrophbic_section
# 349           PEOE_VSA6_S  hydrophilic_section   hydrophbic_section
# 350                Comp.1          T of comp.1          T of solv.1
# 351                Comp.1          T of comp.1          T of solv.1
# 352                Comp.1          T of comp.1          T of solv.1
# 353                Comp.1          T of comp.1          T of solv.1
# 354                Comp.1          T of comp.1          hydrophilic
# 355                Comp.1          T of comp.1          hydrophilic
# 356                Comp.1          T of comp.1          hydrophilic
# 357                Comp.1          T of comp.1  hydrophilic_section
# 358                Comp.1          T of comp.1  hydrophilic_section
# 359                Comp.1          T of comp.1   hydrophbic_section
# 360                Comp.1          T of solv.1          hydrophilic
# 361                Comp.1          T of solv.1          hydrophilic
# 362                Comp.1          T of solv.1          hydrophilic
# 363                Comp.1          T of solv.1  hydrophilic_section
# 364                Comp.1          T of solv.1  hydrophilic_section
# 365                Comp.1          T of solv.1   hydrophbic_section
# 366                Comp.1          hydrophilic  hydrophilic_section
# 367                Comp.1          hydrophilic  hydrophilic_section
# 368                Comp.1          hydrophilic   hydrophbic_section
# 369                Comp.1  hydrophilic_section   hydrophbic_section
# 370           T of comp.1          T of solv.1          hydrophilic
# 371           T of comp.1          T of solv.1          hydrophilic
# 372           T of comp.1          T of solv.1          hydrophilic
# 373           T of comp.1          T of solv.1  hydrophilic_section
# 374           T of comp.1          T of solv.1  hydrophilic_section
# 375           T of comp.1          T of solv.1   hydrophbic_section
# 376           T of comp.1          hydrophilic  hydrophilic_section
# 377           T of comp.1          hydrophilic  hydrophilic_section
# 378           T of comp.1          hydrophilic   hydrophbic_section
# 379           T of comp.1  hydrophilic_section   hydrophbic_section
# 380           T of solv.1          hydrophilic  hydrophilic_section
# 381           T of solv.1          hydrophilic  hydrophilic_section
# 382           T of solv.1          hydrophilic   hydrophbic_section
# 383           T of solv.1  hydrophilic_section   hydrophbic_section
# 384           hydrophilic  hydrophilic_section   hydrophbic_section
# 385                TPSA_C                    -                    -
# 386                TPSA_C                    -                    -
# 387                TPSA_C                    -                    -
# 388                TPSA_C                    -                    -
# 389                TPSA_C                    -                    -
# 390                TPSA_C                    -                    -
# 391                TPSA_C                    -                    -
# 392                TPSA_C                    -                    -
# 393                TPSA_C                    -                    -
# 394                TPSA_C                    -                    -
# 395                TPSA_C                    -                    -
# 396                TPSA_C                    -                    -
# 397                TPSA_C                    -                    -
# 398                TPSA_C                    -                    -
# 399                TPSA_C                    -                    -
# 400                TPSA_C                    -                    -
# 401                TPSA_C                    -                    -
# 402                TPSA_C                    -                    -
# 403                TPSA_C                    -                    -
# 404                TPSA_C                    -                    -
# 405                TPSA_C                    -                    -
# 406                TPSA_C                    -                    -
# 407                TPSA_C                    -                    -
# 408                TPSA_C                    -                    -
# 409                TPSA_C                    -                    -
# 410                TPSA_C                    -                    -
# 411                TPSA_C                    -                    -
# 412                TPSA_C                    -                    -
# 413                TPSA_C                    -                    -
# 414                TPSA_C                    -                    -
# 415                TPSA_C                    -                    -
# 416                TPSA_C                    -                    -
# 417                TPSA_C                    -                    -
# 418                TPSA_C                    -                    -
# 419                TPSA_C                    -                    -
# 420                TPSA_C                    -                    -
# 421                TPSA_C                    -                    -
# 422                TPSA_C                    -                    -
# 423                TPSA_C                    -                    -
# 424                TPSA_C                    -                    -
# 425                TPSA_C                    -                    -
# 426                TPSA_C                    -                    -
# 427                TPSA_C                    -                    -
# 428                TPSA_C                    -                    -
# 429                TPSA_C                    -                    -
# 430                TPSA_C                    -                    -
# 431                TPSA_C                    -                    -
# 432                TPSA_C                    -                    -
# 433                TPSA_C                    -                    -
# 434                TPSA_C                    -                    -
# 435                TPSA_C                    -                    -
# 436                TPSA_C                    -                    -
# 437                TPSA_C                    -                    -
# 438                TPSA_C                    -                    -
# 439                TPSA_C                    -                    -
# 440                TPSA_C                    -                    -
# 441                TPSA_C                    -                    -
# 442                TPSA_C                    -                    -
# 443                TPSA_C                    -                    -
# 444                TPSA_C                    -                    -
# 445                TPSA_C                    -                    -
# 446                TPSA_C                    -                    -
# 447                TPSA_C                    -                    -
# 448                TPSA_C                    -                    -
# 449                TPSA_C                    -                    -
# 450                TPSA_C                    -                    -
# 451                TPSA_C                    -                    -
# 452                TPSA_C                    -                    -
# 453                TPSA_C                    -                    -
# 454                TPSA_C                    -                    -
# 455                TPSA_C                    -                    -
# 456                TPSA_C                    -                    -
# 457                TPSA_C                    -                    -
# 458                TPSA_C                    -                    -
# 459                TPSA_C                    -                    -
# 460                TPSA_C                    -                    -
# 461                TPSA_C                    -                    -
# 462                TPSA_C                    -                    -
# 463                TPSA_C                    -                    -
# 464                TPSA_C                    -                    -
# 465                TPSA_C                    -                    -
# 466                TPSA_C                    -                    -
# 467                TPSA_C                    -                    -
# 468                TPSA_C                    -                    -
# 469                TPSA_C                    -                    -
# 470                TPSA_C                    -                    -
# 471                TPSA_C                    -                    -
# 472                TPSA_C                    -                    -
# 473                TPSA_C                    -                    -
# 474                TPSA_C                    -                    -
# 475                TPSA_C                    -                    -
# 476                TPSA_C                    -                    -
# 477                TPSA_C                    -                    -
# 478                TPSA_C                    -                    -
# 479                TPSA_C                    -                    -
# 480                TPSA_C                    -                    -
# 481                TPSA_C                    -                    -
# 482                TPSA_C                    -                    -
# 483                TPSA_C                    -                    -
# 484                TPSA_C                    -                    -
# 485                TPSA_C                    -                    -
# 486                TPSA_C                    -                    -
# 487                TPSA_C                    -                    -
# 488                TPSA_C                    -                    -
# 489                TPSA_C                    -                    -
# 490                TPSA_C                    -                    -
# 491                TPSA_C                    -                    -
# 492                TPSA_C                    -                    -
# 493                TPSA_C                    -                    -
# 494                TPSA_C                    -                    -
# 495                TPSA_C                    -                    -
# 496                TPSA_C                    -                    -
# 497                TPSA_C                    -                    -
# 498                TPSA_C                    -                    -
# 499                TPSA_C                    -                    -
# 500                TPSA_C                    -                    -
# 501                TPSA_C                    -                    -
# 502                TPSA_C                    -                    -
# 503                TPSA_C                    -                    -
# 504                TPSA_C                    -                    -
# 505                TPSA_C                    -                    -
# 506                TPSA_C                    -                    -
# 507                TPSA_C                    -                    -
# 508                TPSA_C                    -                    -
# 509                TPSA_C                    -                    -
# 510                TPSA_C                    -                    -
# 511           PEOE_VSA6_C                    -                    -
# 512           PEOE_VSA6_C                    -                    -
# 513           PEOE_VSA6_C                    -                    -
# 514           PEOE_VSA6_C                    -                    -
# 515           PEOE_VSA6_C                    -                    -
# 516           PEOE_VSA6_C                    -                    -
# 517           PEOE_VSA6_C                    -                    -
# 518           PEOE_VSA6_C                    -                    -
# 519           PEOE_VSA6_C                    -                    -
# 520           PEOE_VSA6_C                    -                    -
# 521           PEOE_VSA6_C                    -                    -
# 522           PEOE_VSA6_C                    -                    -
# 523           PEOE_VSA6_C                    -                    -
# 524           PEOE_VSA6_C                    -                    -
# 525           PEOE_VSA6_C                    -                    -
# 526           PEOE_VSA6_C                    -                    -
# 527           PEOE_VSA6_C                    -                    -
# 528           PEOE_VSA6_C                    -                    -
# 529           PEOE_VSA6_C                    -                    -
# 530           PEOE_VSA6_C                    -                    -
# 531           PEOE_VSA6_C                    -                    -
# 532           PEOE_VSA6_C                    -                    -
# 533           PEOE_VSA6_C                    -                    -
# 534           PEOE_VSA6_C                    -                    -
# 535           PEOE_VSA6_C                    -                    -
# 536           PEOE_VSA6_C                    -                    -
# 537           PEOE_VSA6_C                    -                    -
# 538           PEOE_VSA6_C                    -                    -
# 539           PEOE_VSA6_C                    -                    -
# 540           PEOE_VSA6_C                    -                    -
# 541           PEOE_VSA6_C                    -                    -
# 542           PEOE_VSA6_C                    -                    -
# 543           PEOE_VSA6_C                    -                    -
# 544           PEOE_VSA6_C                    -                    -
# 545           PEOE_VSA6_C                    -                    -
# 546           PEOE_VSA6_C                    -                    -
# 547           PEOE_VSA6_C                    -                    -
# 548           PEOE_VSA6_C                    -                    -
# 549           PEOE_VSA6_C                    -                    -
# 550           PEOE_VSA6_C                    -                    -
# 551           PEOE_VSA6_C                    -                    -
# 552           PEOE_VSA6_C                    -                    -
# 553           PEOE_VSA6_C                    -                    -
# 554           PEOE_VSA6_C                    -                    -
# 555           PEOE_VSA6_C                    -                    -
# 556           PEOE_VSA6_C                    -                    -
# 557           PEOE_VSA6_C                    -                    -
# 558           PEOE_VSA6_C                    -                    -
# 559           PEOE_VSA6_C                    -                    -
# 560           PEOE_VSA6_C                    -                    -
# 561           PEOE_VSA6_C                    -                    -
# 562           PEOE_VSA6_C                    -                    -
# 563           PEOE_VSA6_C                    -                    -
# 564           PEOE_VSA6_C                    -                    -
# 565           PEOE_VSA6_C                    -                    -
# 566           PEOE_VSA6_C                    -                    -
# 567           PEOE_VSA6_C                    -                    -
# 568           PEOE_VSA6_C                    -                    -
# 569           PEOE_VSA6_C                    -                    -
# 570           PEOE_VSA6_C                    -                    -
# 571           PEOE_VSA6_C                    -                    -
# 572           PEOE_VSA6_C                    -                    -
# 573           PEOE_VSA6_C                    -                    -
# 574           PEOE_VSA6_C                    -                    -
# 575           PEOE_VSA6_C                    -                    -
# 576           PEOE_VSA6_C                    -                    -
# 577           PEOE_VSA6_C                    -                    -
# 578           PEOE_VSA6_C                    -                    -
# 579           PEOE_VSA6_C                    -                    -
# 580           PEOE_VSA6_C                    -                    -
# 581           PEOE_VSA6_S                    -                    -
# 582           PEOE_VSA6_S                    -                    -
# 583           PEOE_VSA6_S                    -                    -
# 584           PEOE_VSA6_S                    -                    -
# 585           PEOE_VSA6_S                    -                    -
# 586           PEOE_VSA6_S                    -                    -
# 587           PEOE_VSA6_S                    -                    -
# 588           PEOE_VSA6_S                    -                    -
# 589           PEOE_VSA6_S                    -                    -
# 590           PEOE_VSA6_S                    -                    -
# 591           PEOE_VSA6_S                    -                    -
# 592           PEOE_VSA6_S                    -                    -
# 593           PEOE_VSA6_S                    -                    -
# 594           PEOE_VSA6_S                    -                    -
# 595           PEOE_VSA6_S                    -                    -
# 596           PEOE_VSA6_S                    -                    -
# 597           PEOE_VSA6_S                    -                    -
# 598           PEOE_VSA6_S                    -                    -
# 599           PEOE_VSA6_S                    -                    -
# 600           PEOE_VSA6_S                    -                    -
# 601           PEOE_VSA6_S                    -                    -
# 602           PEOE_VSA6_S                    -                    -
# 603           PEOE_VSA6_S                    -                    -
# 604           PEOE_VSA6_S                    -                    -
# 605           PEOE_VSA6_S                    -                    -
# 606           PEOE_VSA6_S                    -                    -
# 607           PEOE_VSA6_S                    -                    -
# 608           PEOE_VSA6_S                    -                    -
# 609           PEOE_VSA6_S                    -                    -
# 610           PEOE_VSA6_S                    -                    -
# 611           PEOE_VSA6_S                    -                    -
# 612           PEOE_VSA6_S                    -                    -
# 613           PEOE_VSA6_S                    -                    -
# 614           PEOE_VSA6_S                    -                    -
# 615           PEOE_VSA6_S                    -                    -
# 616                Comp.1                    -                    -
# 617                Comp.1                    -                    -
# 618                Comp.1                    -                    -
# 619                Comp.1                    -                    -
# 620                Comp.1                    -                    -
# 621                Comp.1                    -                    -
# 622                Comp.1                    -                    -
# 623                Comp.1                    -                    -
# 624                Comp.1                    -                    -
# 625                Comp.1                    -                    -
# 626                Comp.1                    -                    -
# 627                Comp.1                    -                    -
# 628                Comp.1                    -                    -
# 629                Comp.1                    -                    -
# 630                Comp.1                    -                    -
# 631           T of comp.1                    -                    -
# 632           T of comp.1                    -                    -
# 633           T of comp.1                    -                    -
# 634           T of comp.1                    -                    -
# 635           T of comp.1                    -                    -
# 636           T of solv.1                    -                    -
# 637                TPSA_C                    -                    -
# 638                TPSA_C                    -                    -
# 639                TPSA_C                    -                    -
# 640                TPSA_C                    -                    -
# 641                TPSA_C                    -                    -
# 642                TPSA_C                    -                    -
# 643                TPSA_C                    -                    -
# 644                TPSA_C                    -                    -
# 645                TPSA_C                    -                    -
# 646                TPSA_C                    -                    -
# 647                TPSA_C                    -                    -
# 648                TPSA_C                    -                    -
# 649                TPSA_C                    -                    -
# 650                TPSA_C                    -                    -
# 651                TPSA_C                    -                    -
# 652                TPSA_C                    -                    -
# 653                TPSA_C                    -                    -
# 654                TPSA_C                    -                    -
# 655                TPSA_C                    -                    -
# 656                TPSA_C                    -                    -
# 657                TPSA_C                    -                    -
# 658                TPSA_C                    -                    -
# 659                TPSA_C                    -                    -
# 660                TPSA_C                    -                    -
# 661                TPSA_C                    -                    -
# 662                TPSA_C                    -                    -
# 663                TPSA_C                    -                    -
# 664                TPSA_C                    -                    -
# 665                TPSA_C                    -                    -
# 666                TPSA_C                    -                    -
# 667                TPSA_C                    -                    -
# 668                TPSA_C                    -                    -
# 669                TPSA_C                    -                    -
# 670                TPSA_C                    -                    -
# 671                TPSA_C                    -                    -
# 672                TPSA_C                    -                    -
# ...
# 697   0.000000e+00  0.000000e+00  0.000000e+00
# 976   0.000000e+00  0.000000e+00  0.000000e+00
# 977   0.000000e+00  0.000000e+00  0.000000e+00
# 978   0.000000e+00  0.000000e+00  0.000000e+00
# 979   0.000000e+00  0.000000e+00  0.000000e+00
# 980   0.000000e+00  0.000000e+00  0.000000e+00
# 981   0.000000e+00  0.000000e+00  0.000000e+00
# 982   0.000000e+00  0.000000e+00  0.000000e+00
# 983   0.000000e+00  0.000000e+00  0.000000e+00
# 984   0.000000e+00  0.000000e+00  0.000000e+00
# 985   0.000000e+00  0.000000e+00  0.000000e+00
# 986   0.000000e+00  0.000000e+00  0.000000e+00
# 987   0.000000e+00  0.000000e+00  0.000000e+00
# 988   0.000000e+00  0.000000e+00  0.000000e+00
# 989   0.000000e+00  0.000000e+00  0.000000e+00
# 990   0.000000e+00  0.000000e+00  0.000000e+00
# 991   0.000000e+00  0.000000e+00  0.000000e+00
# 992   0.000000e+00  0.000000e+00  0.000000e+00
# 993   0.000000e+00  0.000000e+00  0.000000e+00
# 994   0.000000e+00  0.000000e+00  0.000000e+00
# 995   0.000000e+00  0.000000e+00  0.000000e+00
# 996   0.000000e+00  0.000000e+00  0.000000e+00
# 997   0.000000e+00  0.000000e+00  0.000000e+00
# 998   0.000000e+00  0.000000e+00  0.000000e+00
# 999   0.000000e+00  0.000000e+00  0.000000e+00
# 1000  0.000000e+00  0.000000e+00  0.000000e+00
# 1001  0.000000e+00  0.000000e+00  0.000000e+00
# 1002  0.000000e+00  0.000000e+00  0.000000e+00
# 1003  0.000000e+00  0.000000e+00  0.000000e+00
# 1004  0.000000e+00  0.000000e+00  0.000000e+00
# 1005  0.000000e+00  0.000000e+00  0.000000e+00
# 1006  0.000000e+00  0.000000e+00  0.000000e+00
# 1007  0.000000e+00  0.000000e+00  0.000000e+00
# 1008  0.000000e+00  0.000000e+00  0.000000e+00
# 1009  0.000000e+00  0.000000e+00  0.000000e+00
# 1010  0.000000e+00  0.000000e+00  0.000000e+00
# 1011  0.000000e+00  0.000000e+00  0.000000e+00
# 1012  0.000000e+00  0.000000e+00  0.000000e+00
# 1013  0.000000e+00  0.000000e+00  0.000000e+00
# 1014  0.000000e+00  0.000000e+00  0.000000e+00
# 1015  0.000000e+00  0.000000e+00  0.000000e+00
# 1016  0.000000e+00  0.000000e+00  0.000000e+00
# 1017  0.000000e+00  0.000000e+00  0.000000e+00
# 1018  0.000000e+00  0.000000e+00  0.000000e+00
# 1019  0.000000e+00  0.000000e+00  0.000000e+00
# 1020  0.000000e+00  0.000000e+00  0.000000e+00
# 1021  0.000000e+00  0.000000e+00  0.000000e+00
# 1022  0.000000e+00  0.000000e+00  0.000000e+00

# %%
res_7.to_csv("Phase_3_Results_Hybrid_Conditions-MPS.csv", index = False)

# %% [markdown]
# # Dispersity

# %%
base_data_8 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_3_(RD-desc_SYnthesis)\Data_Synthesis_Dispersity.csv")
base_data_8
# Out:
#     Comp     Solvent  T of comp  T of solv  Conc of comp  Polar_dispersity  \
# 0    156  Chloroform         23         23       0.00010          0.303887
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 131071/131071 [18:38<00:00, 117.14it/s]
#                   Desc_1 Desc_2 Desc_3 Desc_4      MSE        r2       MAE  \
# 0          VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 1          Estate_VSA8_C      -      -      -  0.10957 -3.291148  0.283507
# 2          Estate_VSA8_S      -      -      -  0.08686 -2.401768  0.260785
# 3           SlogP_VSA4_C      -      -      -  0.10957 -3.291148  0.283507
# 4           SlogP_VSA4_S      -      -      -  0.08686 -2.401768  0.260785
# ...                  ...    ...    ...    ...      ...       ...       ...
# 131066     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 131067     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 131068     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
# 131069     Estate_VSA8_C      -      -      -  0.10957 -3.291148  0.283507
# 131070     VSA_EState2_C      -      -      -  0.10957 -3.291148  0.283507
#
#               C1   C2   C3   C4
# 0       0.000846  0.0  0.0  0.0
# 1      -0.000273  0.0  0.0  0.0
# 2       0.002952  0.0  0.0  0.0
# 3       0.000890  0.0  0.0  0.0
# 4       0.008124  0.0  0.0  0.0
# ...          ...  ...  ...  ...
# 131066  0.000846  0.0  0.0  0.0
# 131067  0.000846  0.0  0.0  0.0
# 131068  0.000846  0.0  0.0  0.0
# 131069 -0.000273  0.0  0.0  0.0
# 131070  0.000846  0.0  0.0  0.0
#
# [131071 rows x 11 columns]

# %%
res_8.to_csv("Phase_3_Results_Hybrid_Conditions-Dispersity.csv", index = False)

# %% [markdown]
# # Ration of Sphere Vs substance

# %%
base_data_9 = pd.read_csv(r"Z:\Calix Paper\Calix\Relation_3_(RD-desc_SYnthesis)\Data_Synthesis_A1A2.csv")
base_data_9
# Out:
#     Comp  Solvent  T of comp  T of solv  Conc of comp  Area_Sphere_Substance  \
# 0    156        1         23         23       0.00010                 0.4424
# 1    156        1         23          4       0.00010                 0.4434
# 2    156        1          4         23       0.00010                 0.1225
# 3    156        1         23         23       0.00001                 0.3281
# 4    156        2         23         23       0.00010                 0.4510
# 5    156        2         23         23       0.00001                 0.0391
# 6    159        1         23         23       0.00010                 0.0000
# 7    159        1         23         23       0.00001                 0.4323
# 8    159        2         23         23       0.00010                 0.2474
# 9    159        2         23         23       0.00001                 0.2629
# 10   159        1         23          4       0.00010                 0.2474
# 11   159        1          4         23       0.00010                 0.0000
#
#     hydrophilic_section  hydrophbic_section  hydrophilic  VSA_EState2  \
# 0              0.578597            0.549443    1074.3192     6.492710
# 1              0.578597            0.549443    1074.3192     6.492710
# 2              0.578597            0.549443    1074.3192     6.492710
# 3              0.578597            0.549443    1074.3192     6.492710
# 4              0.590875            0.551821    1068.2255     6.492710
# 5              0.590875            0.551821    1068.2255     6.492710
# 6              0.433544            0.509058    3387.1829    49.043023
# 7              0.433544            0.509058    3387.1829    49.043023
# 8              0.433292            0.516996    3435.9498    49.043023
# 9              0.433292            0.516996    3435.9498    49.043023
# 10             0.433544            0.509058    3387.1829    49.043023
# 11             0.433544            0.509058    3387.1829    49.043023
#
#     Estate_VSA8_C  Estate_VSA8_S  SlogP_VSA4_C  SlogP_VSA4_S  EState_VSA2  \
# 0      131.615783       0.000000      0.000000      0.000000    33.158986
# 1      131.615783       0.000000      0.000000      0.000000    33.158986
# 2      131.615783       0.000000      0.000000      0.000000    33.158986
# 3      131.615783       0.000000      0.000000      0.000000    33.158986
# 4      131.615783      19.056471      0.000000      6.923737    33.158986
# 5      131.615783      19.056471      0.000000      6.923737    33.158986
# 6        0.000000       0.000000     40.457273      0.000000   167.872027
# 7        0.000000       0.000000     40.457273      0.000000   167.872027
# 8        0.000000      19.056471     40.457273      6.923737   167.872027
# 9        0.000000      19.056471     40.457273      6.923737   167.872027
# 10       0.000000       0.000000     40.457273      0.000000   167.872027
# 11       0.000000       0.000000     40.457273      0.000000   167.872027
#
#     EState_VSA10  NOCount  NumAliphaticHeterocycles  NumAliphaticRings    TPSA
# 0      10.213055        6                         2                  2   77.38
# 1      10.213055        6                         2                  2   77.38
# 2      10.213055        6                         2                  2   77.38
# 3      10.213055        6                         2                  2   77.38
# 4      10.213055        6                         2                  2   77.38
# 5      10.213055        6                         2                  2   77.38
# 6      40.457273       22                         3                  3  264.86
# 7      40.457273       22                         3                  3  264.86
# 8      40.457273       22                         3                  3  264.86
# 9      40.457273       22                         3                  3  264.86
# 10     40.457273       22                         3                  3  264.86
# 11     40.457273       22                         3                  3  264.86

# %%
res_9 = model_maker(base_data_9,3)
res_9
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 16383/16383 [01:45<00:00, 155.18it/s]
#                     Desc_1 Desc_2 Desc_3 Desc_4       MSE        r2       MAE  \
# 0      hydrophilic_section      -      -      -  0.061078 -0.712471  0.224297
# 1       hydrophbic_section      -      -      -  0.067348 -0.888264  0.237293
# 2              hydrophilic      -      -      -  0.057789 -0.620240  0.216843
# 3              VSA_EState2      -      -      -  0.058212 -0.632095  0.217775
# 4            Estate_VSA8_C      -      -      -  0.058212 -0.632095  0.217775
# ...                    ...    ...    ...    ...       ...       ...       ...
# 16378  hydrophilic_section      -      -      -  0.061078 -0.712471  0.224297
# 16379  hydrophilic_section      -      -      -  0.061078 -0.712471  0.224297
# 16380  hydrophilic_section      -      -      -  0.061078 -0.712471  0.224297
# 16381   hydrophbic_section      -      -      -  0.067348 -0.888264  0.237293
# 16382  hydrophilic_section      -      -      -  0.061078 -0.712471  0.224297
#
#              C1   C2   C3   C4
# 0     -0.333913  0.0  0.0  0.0
# 1     -1.697678  0.0  0.0  0.0
# 2      0.000016  0.0  0.0  0.0
# 3      0.000919  0.0  0.0  0.0
# 4     -0.000297  0.0  0.0  0.0
# ...         ...  ...  ...  ...
# 16378 -0.333913  0.0  0.0  0.0
# 16379 -0.333913  0.0  0.0  0.0
# 16380 -0.333913  0.0  0.0  0.0
# 16381 -1.697678  0.0  0.0  0.0
# 16382 -0.333913  0.0  0.0  0.0
#
# [16383 rows x 11 columns]

# %%
res_9.to_csv("Phase_3_Results_Hybrid_Conditions-Ratio_A1-A2.csv", index = False)

# %% [markdown]
# ------

# %% [markdown]
# --------
